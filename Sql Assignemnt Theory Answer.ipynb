# %% [markdown]
# Here's Are Answer Of All Therotical Answer
# 1.  Explain the fundamental differences between DDL, DML, and DQL
# commands in SQL. Provide one example for each type of command.
# -> There Are Totally 5 Types Of Sql Command We Used Only 3 In Sql
# That Are DDL,DML,DQL
# I. DDL Data Defination Language
# - Which Defines The Data Structure
# - Which Helps To Create And Modify Columns
# - Example = Create, Alter, Drop, Truncate, Rename, Modify
# - Ex. = CREATE, ALTERM ,DROP, TRUNCATE, RENAME
# II. DML Data Manipulation Language
# - It Is Used For Manipulating Data Not The Structure
# - Ex. INSERT, UPDATE, DELETE
# III. DQL Data Query Language
# - It Is Used To Get The Data infront Of Us Like Print Does In Python
# - Ex. SELECT
#
#
#
# 2.What is the purpose of SQL constraints? Name and describe three common types
# of constraints, providing a simple scenario where each would be useful.
# -> Constraints Are Condition We Applied On Column Or Table To Control Data Type Entered And Maintain Accurency, Data Integrity, And Limited Duplication Of Data
# I. Primary Key
# - It's Allowes Only Unique And Not Null Value
# - Helps To Identify Every Row Uniquely In Table
# - It Can Be Only One In One Table And Foreign Key Can Be Multiple
# - Ex. For Indetifying Every Product Uniquely We Can Use Primary Key As Column Name ProductID As Every Product Will Have Unique ProductID
# II. Not Null
# - It's Just Ensure That In Every Single Row Of The Assigned Column Must Have Something Value, It Must Not Be Null i.e. Empty
# - Ex. Employee Name Column Must Have a Value If Not It Can Be Big Problem
# III. Foreign Key
# - It's Makes The Condition Between Two Columns For Taking Joins In Between
# - It's Represent The Primary Key Of Another Column
# - It Can Be More Than One Like Fact Table Has Whole Primary Key As Foreign Key
# - Ex. Product And Category Table There Must Be Connection Between This Two Tables For Effective Data Analysis
#
#
#
# 3. Explain the difference between LIMIT and OFFSET clauses in SQL. How
# would you use them together to retrieve the third page of results, assuming each page has 10 records?
# - Limit And Offset Is Used When We Want To Display The Result In Between Data Of Table Ex. Row After 10 Rows
# - Limit This Is Use For Showing The Limited Data As We Put How Must Data We Want To Display And See And Offset Skip That Must Row We Don't Want To See And Display Next Rows As Per limit Condition
# Ex. LIMIT 10 OFFSET 10 = Offset Skip First 10 Rows And Limit Shows 10 Rows Next After Offset No Matter Table Has How Many Number Of Rows
# - Order By Cluase Can Give Effect On Limit And Offset Function
# - Sql Server Has This OFFSET 5 ROWS FETCH NEXT 5 ROWS ONLY Instead Of Limit And Offset And Also Having Top And Bottom Function In Select Clause
# - For Getting Third Page Result We Have To Run Query Like
# "LIMIT 10 OFFSET 20"
#
#
#
# 4. What is a Common Table Expression (CTE) in SQL, and what are its main
# benefits? Provide a simple SQL example demonstrating its usage.
# -> CTE In Sql Is Means To Creating Temporary Column Or Table To Get Expected Answer Display
# - It Just Exist For That Specific Query And Not Display In Database
# - Syntax =  "With Temporary Name As (Query),Another Cte Name As (Query) "
# - For Getting CTE In Final Query We Have To Take Join Based On Column In Select Cluase And Uniquely Identification And If Not Column For Getting Join Then We Have To Take a Cross Join For Connecting With Join
# - Benifits
# i. Can Creates In Run Time
# ii. Reduces The SubQueries And Complecity Of Query And Make It Simpler
# iii. Helpful For Hierarchical Data Like Employee And Manager Relationship
# Customer And Employee Relationship As Employee Can Be Customer Of Company
# Ex. Amazon, Google
#
#
#
#
#
# 5. Describe the concept of SQL Normalization and its primary goals. Briefly
# explain the first three normal forms (1NF, 2NF, 3NF)
# -> Normalization Is The Process Which Used To Removes Duplicate And Improve Data Integrity Within The Database
# 1St Form Of Noramlization Says The Column Must Not Contains Multivalue Data Or Comma Seprated Data With The Column ie. Every Column Must Contains One Value Only
# 2nd Form States 1St Form And All Non-Key Column In Same Table Must Has Only One Primary Key And Non Key Column Must Depend On Primary Key
# There Must Be Fully Dependency Not Partially Dependency
# 3rd Form Includes 1st And 2nd Form Too With No Transitive Dependency Meaning Non-Key Value/ Column Must Does Not Represent The Non-Key Column
